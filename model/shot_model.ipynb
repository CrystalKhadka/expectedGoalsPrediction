# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Load the dataset
haaland_shots_data = pd.read_csv('../data/raw/haaland_shot_map.csv')

# Select relevant features and target
features = ['X', 'Y', 'shotType', 'lastAction', 'situation']
target = 'xG'
data = haaland_shots_data[features + [target]].dropna()

# Preprocess data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['X', 'Y']),
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['shotType', 'lastAction', 'situation'])
    ]
)
X = data[features]
y = data[target]
X_processed = preprocessor.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# Define models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, random_state=42),
}

# Train and evaluate traditional models
results = []
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    results.append({"Model": name, "MSE": mse, "R²": r2})

# Add neural network model
input_dim = X_train.shape[1]

# Define Neural Network architecture
nn_model = Sequential([
    Dense(64, input_dim=input_dim, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='linear')
])

# Compile the neural network
nn_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse'])

# Train the neural network for 50 epochs
history = nn_model.fit(
    X_train,
    y_train,
    epochs=50,  # Change to 60 for 60 epochs
    batch_size=32,
    validation_split=0.1,
    verbose=1
)

# Evaluate the neural network
y_pred_nn = nn_model.predict(X_test, batch_size=32).flatten()
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

# Add neural network results
results.append({"Model": "Neural Network", "MSE": mse_nn, "R²": r2_nn})

# Convert results to a DataFrame for better readability
results_df = pd.DataFrame(results)
results_df.to_csv("../data/model/model_comparison_results.csv")
print(results_df)
# Out:
# D:\sem6\thesis\data_collection\football\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1445 - mse: 0.1445 - val_loss: 0.0686 - val_mse: 0.0686
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0865 - mse: 0.0865 - val_loss: 0.0535 - val_mse: 0.0535
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0473 - val_mse: 0.0473
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0519 - mse: 0.0519 - val_loss: 0.0384 - val_mse: 0.0384
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0362 - val_mse: 0.0362
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0340 - val_mse: 0.0340
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0377 - mse: 0.0377 - val_loss: 0.0301 - val_mse: 0.0301
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0431 - mse: 0.0431 - val_loss: 0.0317 - val_mse: 0.0317
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0403 - mse: 0.0403 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0372 - mse: 0.0372 - val_loss: 0.0282 - val_mse: 0.0282
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0324 - mse: 0.0324 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.0257 - val_mse: 0.0257
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0375 - mse: 0.0375 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0311 - mse: 0.0311 - val_loss: 0.0258 - val_mse: 0.0258
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0230 - val_mse: 0.0230
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0290 - mse: 0.0290 - val_loss: 0.0216 - val_mse: 0.0216
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0213 - val_mse: 0.0213
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0222 - val_mse: 0.0222
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0223 - mse: 0.0223 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0139 - val_mse: 0.0139
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#                Model       MSE        R²
# 0  Linear Regression  0.030921  0.364078
# 1      Random Forest  0.020691  0.574473
# 2  Gradient Boosting  0.018450  0.620554
# 3     Neural Network  0.019798  0.592838
